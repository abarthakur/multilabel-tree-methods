# %% [markdown]
# # Experiments Overview

# %% [markdown]
# ### Model Overview
#
# Let's first take a look at the parabel model
#
# * It is a label tree, with "distributions" not classifiers at each node.
#     * Practically, this means we will be dealing in the probabilities not hard labels.
# * Representation used is as implemented in utils.generate_parabel_representations.
# * Partitioning algorithm is as implemented in partition.ParabelPartitioner
#     * Hyperparameter : M = size of the leaf
# * Each internal/leaf classifier is binary relevance of SVMs.
#     * SVMs are trained with squared hinge loss/log loss & L2 regularization.
#     * Hyperparameter : SHL vs LL
#     * Hyperparameter : C = misclassification penalty.
# * Prediction is done by beam search over the tree.
#     * Hyperparameter : P = width of beam/number of solutions
# * Finally, parabel is also considered as an ensemble.
#     * Hyperparameter : T = number of trees
#
#
# Regarding the classifiers, we will use sklearn.svm.LinearSVC, which is based on liblinear implementation and is hopefully close to original results.
#
# ### Experiment 2
#
# The paper reports P@1,P@3,P@5 on the following (open) datasets
#
# - [ ] Eurlex-4k
# - [ ] WikiLSHTC-325k
# - [ ] Amazon-3M
# - [ ] Wiki500k
# - [ ] Amazon-670k
#
# The hyperparameters used are
#
# * M=100, P=10
# * (loss,C,T) == (SHL,1,1) ; (SHL,1,3) ; (LL,10,3)
#
#
# ### Experiment 1
#
#
# The XML repo additionally reports P@1,P@3,P@5 on the following small datasets
#
# - [x] Mediamill
# - [ ] Delicious
# - [ ] Bibtex
#
# Since hyperparameters are not reported, we will use the following values
#
# * M=5
# * P=10
# * loss = SHL, C=1
# * T=1

# %%
# %%HTML
# <style>
# td,th {
#   font-size: 16px
# }
# </style>
# Out:
# <style>
# td,th {
#   font-size: 16px
# }
# </style>

# %% [markdown]
# The performances reported for Parabel are
#
#
# | Dataset | P@1 | P@3 | P@5 |
# |---------|-----|-----|-----|
# |Mediamill|83.91|67.12|52.99|
# |Delicious|67.44|61.83|56.75|
# |Eurlex-4k|81.73|68.78|57.44|

# %% [markdown]
# ## Initialization

# %%
import sys
sys.path.append("..")

# %%
import pandas as pd

# %%
def average_over_repetitions(results):
    mean_results=results.groupby(["num_trees","dataset"]).mean()
    mean_results=mean_results.drop(columns=["rep_num"])
    mean_results.reset_index(inplace=True)
    return mean_results

# %%
results=None
with open("../experiments/prabhu_results.csv","r") as fi:
    results=pd.read_csv(fi)

# %%
results
# Out:
#           p@1       p@3       p@5  ranking_loss  coverage_error  \
# 0    0.551491  0.327899  0.242783      0.189450       50.363419
# 1    0.568588  0.347515  0.259801      0.122763       34.896223
# 2    0.574155  0.353214  0.260199      0.110035       31.765805
# 3    0.550298  0.330285  0.242624      0.185564       49.004771
# 4    0.562624  0.343804  0.255348      0.137608       38.144732
# ..        ...       ...       ...           ...             ...
# 145  0.831733  0.669480  0.525306      0.089976       32.884931
# 146  0.837463  0.669325  0.529549      0.088493       31.395927
# 147  0.797661  0.660704  0.505405      0.128862       41.123742
# 148  0.837463  0.673791  0.531470      0.084843       31.080223
# 149  0.825383  0.671287  0.529952      0.080665       29.598807
#
#      avg_prec_score    ndcg@1    ndcg@3    ndcg@5     dcg@1     dcg@3  \
# 0          0.500738  0.551491  0.501579  0.521157  0.551491  0.801902
# 1          0.526970  0.568588  0.526592  0.550226  0.568588  0.842321
# 2          0.535899  0.574155  0.534970  0.555603  0.574155  0.855162
# 3          0.502397  0.550298  0.503217  0.519961  0.550298  0.805248
# 4          0.519425  0.562624  0.519753  0.541129  0.562624  0.834188
# ..              ...       ...       ...       ...       ...       ...
# 145        0.714298  0.831733  0.748293  0.714287  0.831733  1.513889
# 146        0.718075  0.837463  0.749311  0.717949  0.837463  1.516501
# 147        0.682836  0.797661  0.732505  0.689343  0.797661  1.488028
# 148        0.722578  0.837463  0.752333  0.720141  0.837463  1.523473
# 149        0.720014  0.825383  0.747441  0.715549  0.825383  1.514894
#
#         dcg@5    dataset  split  rep_num  num_trees
# 0    0.896626     bibtex    0.0      0.0        1.0
# 1    0.947737     bibtex    0.0      0.0        2.0
# 2    0.954925     bibtex    0.0      0.0        3.0
# 3    0.896617     bibtex    0.0      1.0        1.0
# 4    0.935210     bibtex    0.0      1.0        2.0
# ..        ...        ...    ...      ...        ...
# 145  1.768072  mediamill    2.0      3.0        2.0
# 146  1.779330  mediamill    2.0      3.0        3.0
# 147  1.712349  mediamill    2.0      4.0        1.0
# 148  1.784902  mediamill    2.0      4.0        2.0
# 149  1.776273  mediamill    2.0      4.0        3.0
#
# [150 rows x 16 columns]

# %%
mean_results=average_over_repetitions(results)
filtered=mean_results.filter(["p@1","p@3","p@5","ndcg@1","ndcg@3","ndcg@5","dcg@1","dcg@3","dcg@5","num_trees","dataset"])
mediamill_results=filtered[filtered["dataset"]=="mediamill"]
delicious_results=filtered[filtered["dataset"]=="delicious"]
bibtex_results=filtered[filtered["dataset"]=="bibtex"]
eurlex_results=filtered[filtered["dataset"]=="eurlex"]

# %% [markdown]
# ### Mediamill

# %%
display(mediamill_results)
# Out:
#         p@1       p@3       p@5    ndcg@1    ndcg@3    ndcg@5     dcg@1  \
# 2  0.808430  0.658875  0.507601  0.808430  0.733224  0.693589  0.808430
# 5  0.823804  0.666250  0.522637  0.823804  0.742700  0.709566  0.823804
# 8  0.820634  0.669477  0.526332  0.820634  0.744593  0.712395  0.820634
#
#       dcg@3     dcg@5  num_trees    dataset
# 2  1.487838  1.718968        1.0  mediamill
# 5  1.505785  1.758438        2.0  mediamill
# 8  1.509789  1.766082        3.0  mediamill

# %% [markdown]
# **Results are close to reported.**

# %% [markdown]
# ### Delicious

# %%
display(delicious_results)
# Out:
#         p@1       p@3       p@5    ndcg@1    ndcg@3    ndcg@5     dcg@1  \
# 1  0.621622  0.567389  0.524149  0.621622  0.580360  0.548087  0.621622
# 4  0.643203  0.586422  0.540689  0.643203  0.600071  0.565936  0.643203
# 7  0.648687  0.592493  0.545658  0.648687  0.606083  0.571185  0.648687
#
#       dcg@3     dcg@5  num_trees    dataset
# 1  1.235881  1.612156        1.0  delicious
# 4  1.277935  1.664711        2.0  delicious
# 7  1.290747  1.680148        3.0  delicious

# %% [markdown]
# **P@k measures are off by about 4% from reported**. Possible reasons -
#
# * We chose leaf size M=5 ad-hoc.
# * Weight clipping (which is essentially a regularization trick) was applied in the original paper, which we did not implement

# %% [markdown]
# ### Bibtex

# %%
display(bibtex_results)
# Out:
#         p@1       p@3       p@5    ndcg@1    ndcg@3    ndcg@5     dcg@1  \
# 0  0.555176  0.332158  0.245042  0.555176  0.507202  0.527429  0.555176
# 4  0.569463  0.345942  0.255968  0.569463  0.525591  0.547430  0.569463
# 8  0.579642  0.354478  0.261848  0.579642  0.537892  0.560146  0.579642
#
#       dcg@3     dcg@5  num_trees dataset
# 0  0.810629  0.904631        1.0  bibtex
# 4  0.840336  0.939950        2.0  bibtex
# 8  0.859565  0.960747        3.0  bibtex

# %% [markdown]
# **Results are off by about 10% from reported.**

# %% [markdown]
# ### Eurlex

# %%
display(eurlex_results)
# Out:
#          p@1       p@3       p@5    ndcg@1    ndcg@3    ndcg@5     dcg@1  \
# 2   0.663691  0.529815  0.430654  0.663787  0.563047  0.508288  0.663787
# 6   0.700814  0.571139  0.470570  0.700866  0.603868  0.550209  0.700866
# 10  0.727067  0.591459  0.486931  0.727049  0.625575  0.569746  0.727049
#
#        dcg@3     dcg@5  num_trees dataset
# 2   1.193999  1.426257        1.0  eurlex
# 6   1.280629  1.543641        2.0  eurlex
# 10  1.326516  1.598203        3.0  eurlex

# %% [markdown]
# **Results are off by about 10% from reported**
